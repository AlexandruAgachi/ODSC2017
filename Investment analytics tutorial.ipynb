# %% [markdown]
# # Investment analytics tutorial
#
# # https://github.com/AlexandruAgachi/ODSC2017

# %% [markdown]
# A couple of first points:
#
# 1. Thank you for being here
# 2. This is an opportunity to learn together and share best practices and preferences, not a lecture
# 3. I am here on a voluntary basis, delighted to be here, and will remain available in the future if I can assist you:
# m.a.agachi[at]gmail.com
# 4. Tutorial covers investment analytics as used in practice by many investment firms. Designed for a beginner to
# intermediary level audience wishing to implement them in python/pandas
# 5. The words "manager", "strategy", "portfolio", "fund", "model" are equivalent in this tutorial. The analytics we will review here apply equally to a manager, a fund, a model or a strategy.
# 6. What motivated this tutorial
# a. Few people in the industry know these concepts inside out
# b. Can help industry with its identity crisis. Active management should focus on qualitative outperformance, not just performance
# c. The lines between different types of asset managers are getting blurry Breaking down their return streams gives you insight into how they generate them, and therefore what you invest in
# 7. Python packages and pandas still lack many functions used in finance. Where this is the case, we will implement them manually here
# 8. As we are a data science community, I will comment the code/packages/functions here and there
# 9. Please contribute to open data

# %% [markdown]
# What is an investment?
#
# > Investment is an initial forfeit of something we value in exchange for the anticipated
# > benefit of getting back more than we put in. The difference between what we put in and
# > what we got back is the return; we invest in order to yield this return.
#
# > Bruce Feibel
#
# Why investment analytics?
#
# These are your road indicators as an investor in the alternative space. Without robust analysis you are blind, as an investor and as an allocator.

# %% [markdown]
# What are investment analytics?
#
# The study of time series. Everything you do as an operator on the markets in finance
# is time dependent. Time is a constraint in your input, and a determinant of your output. These statistics are time sensitive.
#
# > More formally, investment analytics are "the calculation of return, risk, and derived statistics stemming from the periodic change
# > in market value of portfolio positions and transactions made into and within a portfolio,
# > for use in the evaluation of historical fund or manager performance."
#
# > Bruce Feibel

# %% [markdown]
# Backward looking or forward looking?
#
# They are backward looking, yet by necessity we use them to make forward looking projections.
#
# The same for all asset classes and strategies?
#
# Yes - this is one of the reasons they are so useful.

# %% [markdown]
# Overview:
# 1. Performance and basic statistical concepts
# 2. Risk adjusted performance analysis
# 3. Skill and performance attribution
#
# !Formulas here as per Feibel (2003). The best book on investment analytics in my opinion.

# %% [markdown]
# ## Performance and basic statistical concepts - The value of time
#
# Key question throughout this section - How has the value of the portfolio changed over time?

# %%
#let's import our packages
import pandas as pd
import numpy as np
import seaborn as sns
import scipy
import math
import statsmodels.formula.api as smf
import statsmodels.stats.multicomp as multi
import statsmodels.api as sm
from scipy.stats.stats import pearsonr
# %matplotlib inline

# %%
cd Dropbox/Investment performance analysis presentation/presentation
# Out:
# [Errno 2] No such file or directory: 'Dropbox/Investment performance analysis presentation/presentation'
# /Users/aa/Dropbox/Investment performance analysis presentation/presentation

# %% [markdown]
# #You can download this dataset at this following address:
# http://pages.stern.nyu.edu/~adamodar/New_Home_Page/datafile/histretSP.html
#
# You will then need to open it and save it as a csv on your computer, renaming the file "S&P 500.csv"
#
# Many thanks to Aswath Damodaran, not only for this dataset but more generally for his terrific resources, openly available.

# %%
sp500 = pd.read_csv("S&P 500.csv")

# %%
sp500
# Out:
#     Year     Date  Unnamed: 2  Unnamed: 3  Unnamed: 4
# 0   1928   43.81%         NaN         NaN         NaN
# 1   1929   -8.30%         NaN         NaN         NaN
# 2   1930  -25.12%         NaN         NaN         NaN
# 3   1931  -43.84%         NaN         NaN         NaN
# 4   1932   -8.64%         NaN         NaN         NaN
# 5   1933   49.98%         NaN         NaN         NaN
# 6   1934   -1.19%         NaN         NaN         NaN
# 7   1935   46.74%         NaN         NaN         NaN
# 8   1936   31.94%         NaN         NaN         NaN
# 9   1937  -35.34%         NaN         NaN         NaN
# 10  1938   29.28%         NaN         NaN         NaN
# 11  1939   -1.10%         NaN         NaN         NaN
# 12  1940  -10.67%         NaN         NaN         NaN
# 13  1941  -12.77%         NaN         NaN         NaN
# 14  1942   19.17%         NaN         NaN         NaN
# 15  1943   25.06%         NaN         NaN         NaN
# 16  1944   19.03%         NaN         NaN         NaN
# 17  1945   35.82%         NaN         NaN         NaN
# 18  1946   -8.43%         NaN         NaN         NaN
# 19  1947    5.20%         NaN         NaN         NaN
# 20  1948    5.70%         NaN         NaN         NaN
# 21  1949   18.30%         NaN         NaN         NaN
# 22  1950   30.81%         NaN         NaN         NaN
# 23  1951   23.68%         NaN         NaN         NaN
# 24  1952   18.15%         NaN         NaN         NaN
# 25  1953   -1.21%         NaN         NaN         NaN
# 26  1954   52.56%         NaN         NaN         NaN
# 27  1955   32.60%         NaN         NaN         NaN
# 28  1956    7.44%         NaN         NaN         NaN
# 29  1957  -10.46%         NaN         NaN         NaN
# ..   ...      ...         ...         ...         ...
# 59  1987    5.81%         NaN         NaN         NaN
# 60  1988   16.54%         NaN         NaN         NaN
# 61  1989   31.48%         NaN         NaN         NaN
# 62  1990   -3.06%         NaN         NaN         NaN
# 63  1991   30.23%         NaN         NaN         NaN
# 64  1992    7.49%         NaN         NaN         NaN
# 65  1993    9.97%         NaN         NaN         NaN
# 66  1994    1.33%         NaN         NaN         NaN
# 67  1995   37.20%         NaN         NaN         NaN
# 68  1996   22.68%         NaN         NaN         NaN
# 69  1997   33.10%         NaN         NaN         NaN
# 70  1998   28.34%         NaN         NaN         NaN
# 71  1999   20.89%         NaN         NaN         NaN
# 72  2000   -9.03%         NaN         NaN         NaN
# 73  2001  -11.85%         NaN         NaN         NaN
# 74  2002  -21.97%         NaN         NaN         NaN
# 75  2003   28.36%         NaN         NaN         NaN
# 76  2004   10.74%         NaN         NaN         NaN
# 77  2005    4.83%         NaN         NaN         NaN
# 78  2006   15.61%         NaN         NaN         NaN
# 79  2007    5.48%         NaN         NaN         NaN
# 80  2008  -36.55%         NaN         NaN         NaN
# 81  2009   25.94%         NaN         NaN         NaN
# 82  2010   14.82%         NaN         NaN         NaN
# 83  2011    2.10%         NaN         NaN         NaN
# 84  2012   15.89%         NaN         NaN         NaN
# 85  2013   32.15%         NaN         NaN         NaN
# 86  2014   13.52%         NaN         NaN         NaN
# 87  2015    1.36%         NaN         NaN         NaN
# 88  2016   11.74%         NaN         NaN         NaN
#
# [89 rows x 5 columns]

# %%
#let's get rid of the extra columns getting created in the conversion process
sp501 = sp500[['Year', 'Date']]

# %%
sp501
# Out:
#     Year     Date
# 0   1928   43.81%
# 1   1929   -8.30%
# 2   1930  -25.12%
# 3   1931  -43.84%
# 4   1932   -8.64%
# 5   1933   49.98%
# 6   1934   -1.19%
# 7   1935   46.74%
# 8   1936   31.94%
# 9   1937  -35.34%
# 10  1938   29.28%
# 11  1939   -1.10%
# 12  1940  -10.67%
# 13  1941  -12.77%
# 14  1942   19.17%
# 15  1943   25.06%
# 16  1944   19.03%
# 17  1945   35.82%
# 18  1946   -8.43%
# 19  1947    5.20%
# 20  1948    5.70%
# 21  1949   18.30%
# 22  1950   30.81%
# 23  1951   23.68%
# 24  1952   18.15%
# 25  1953   -1.21%
# 26  1954   52.56%
# 27  1955   32.60%
# 28  1956    7.44%
# 29  1957  -10.46%
# ..   ...      ...
# 59  1987    5.81%
# 60  1988   16.54%
# 61  1989   31.48%
# 62  1990   -3.06%
# 63  1991   30.23%
# 64  1992    7.49%
# 65  1993    9.97%
# 66  1994    1.33%
# 67  1995   37.20%
# 68  1996   22.68%
# 69  1997   33.10%
# 70  1998   28.34%
# 71  1999   20.89%
# 72  2000   -9.03%
# 73  2001  -11.85%
# 74  2002  -21.97%
# 75  2003   28.36%
# 76  2004   10.74%
# 77  2005    4.83%
# 78  2006   15.61%
# 79  2007    5.48%
# 80  2008  -36.55%
# 81  2009   25.94%
# 82  2010   14.82%
# 83  2011    2.10%
# 84  2012   15.89%
# 85  2013   32.15%
# 86  2014   13.52%
# 87  2015    1.36%
# 88  2016   11.74%
#
# [89 rows x 2 columns]

# %%
#let's turn the percentages, which pandas now reads as strings, into floats
returns = [float(x[:-1]) for x in sp501['Date']]
#we read these operations from the inside out. Here we tell pandas to keep all but the last character, then convert into
#a float, and do this for each value in the series/column called Date in our dataset.

# %%
sp501['Date'] = returns
# Out:
# //anaconda/lib/python3.6/site-packages/ipykernel/__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':

# %%
sp501.columns = ['Year', 'Value']

# %%
sp501
# Out:
#     Year  Value
# 0   1928  43.81
# 1   1929  -8.30
# 2   1930 -25.12
# 3   1931 -43.84
# 4   1932  -8.64
# 5   1933  49.98
# 6   1934  -1.19
# 7   1935  46.74
# 8   1936  31.94
# 9   1937 -35.34
# 10  1938  29.28
# 11  1939  -1.10
# 12  1940 -10.67
# 13  1941 -12.77
# 14  1942  19.17
# 15  1943  25.06
# 16  1944  19.03
# 17  1945  35.82
# 18  1946  -8.43
# 19  1947   5.20
# 20  1948   5.70
# 21  1949  18.30
# 22  1950  30.81
# 23  1951  23.68
# 24  1952  18.15
# 25  1953  -1.21
# 26  1954  52.56
# 27  1955  32.60
# 28  1956   7.44
# 29  1957 -10.46
# ..   ...    ...
# 59  1987   5.81
# 60  1988  16.54
# 61  1989  31.48
# 62  1990  -3.06
# 63  1991  30.23
# 64  1992   7.49
# 65  1993   9.97
# 66  1994   1.33
# 67  1995  37.20
# 68  1996  22.68
# 69  1997  33.10
# 70  1998  28.34
# 71  1999  20.89
# 72  2000  -9.03
# 73  2001 -11.85
# 74  2002 -21.97
# 75  2003  28.36
# 76  2004  10.74
# 77  2005   4.83
# 78  2006  15.61
# 79  2007   5.48
# 80  2008 -36.55
# 81  2009  25.94
# 82  2010  14.82
# 83  2011   2.10
# 84  2012  15.89
# 85  2013  32.15
# 86  2014  13.52
# 87  2015   1.36
# 88  2016  11.74
#
# [89 rows x 2 columns]

# %%
#as pandas was throwing me an error, I am here forcing it to coerce any unreadable values to the readable pd.nan value,
#and read all Years as numerical values.
sp501['Year'] = pd.to_numeric(sp501['Year'], errors='coerce')
# Out:
# //anaconda/lib/python3.6/site-packages/ipykernel/__main__.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   app.launch_new_instance()

# %%
sp501['Value'] = pd.to_numeric(sp501['Value'])
# Out:
# //anaconda/lib/python3.6/site-packages/ipykernel/__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':

# %%
#Let's take a peek at the annual returns of the S&P 500 since 1928
sp501.set_index('Year')['Value'].plot()

# %%
#average returns
sp_average_return = sp501['Value'].mean()
sp_average_return
# Out:
# 11.415842696629218

# %% [markdown]
# Two concepts around the mean:
#
# 1. Arithmetic mean
#
# 2. Geometric mean

# %% [markdown]
# $arithmetic \ mean \ return = \frac{sum\ of\ returns\ across\ periods}{number \ of \ periods}$

# %% [markdown]
# $geometric\ mean\ return = (\sqrt[N]{(1+cumulative\ return)} - 1) * 100$

# %%
#the geometric mean function offered by most packages, including excel and scipy, cannot handle
#negative values.
#let's write a function here to approximate the geometric mean
#actually let's write two different ones
#if your returns are already expressed as percentages i.e. divided by 100, then simply remove the
#divisions and multiplications by 100 in our formulas here. In our dataframe we are using the
#returns i.e. 43, and not the percentages i.e. 0.43, hence the need for these adjustments here.
#formula per Yuxing Yan (2014)

#Formula 1:
def geomean(x):
    product = 1
    for i in x:
        product *= (1 + i/100)
    return (product ** (1 / len(x))-1)*100

#Formula 2:
ret = sp501['Value']
(pow(scipy.prod(ret/100+1), 1./len(ret))-1)*100

geometric_mean = geomean(sp501['Value'])
geometric_mean
# Out:
# 9.525016349238058

# %% [markdown]
# Why is the geometric mean lower than the arithmetic mean?

# %% [markdown]
# Two more concepts to discuss: Time weighted vs Money weighted value of an investment
#
# Money weighted value reconciles beginning value of an investment with the ending value, adjusting for intermediate cash flows.
#
# Time weighted assumes 1 dollar was invested in the fund on day one, and tracks that dollar over time.
#
# 1. The investor who could not understand why his AUM are not as high as a fund's returns would suggest.
#
# 2. Why investors rarely make as much money on their investments as funds' returns would suggest.
#
# Which one are we focusing on here and why?
#
# We focus on the time weighted one, because we are interested in excluding from our performance measurement everything that is not reflective of the manager's decisions. And the timing and amount of investments does not depend directly on the manager's decisions.
#
# ! Bank Administration Institute, Measuring the Investment Performance of Pension Funds for the Purpose of Inter-Fund Comparison, Bank Administration Institute, Park Ridge, Illinois 1968.

# %%
#Now we have the mean return over this period. Can we therefore expect such a return next year?
#Let's look at the range of the one year rolling returns of the S&P 500 over this period?

sp_average_max = sp501['Value'].max()
sp_average_min = sp501['Value'].min()
sp_average_min, sp_average_max
# Out:
# (-43.840000000000003, 52.560000000000002)

# %% [markdown]
# The answer would be no. We observe a very large variation - what measure would allow us to capture this?

# %% [markdown]
# Standard deviation
#
# The standard deviation represents how far, in average, the observations are from their observed mean.
# In finance it is the fundamental concept of volatility.
#
# Three problems with the standard deviation.
#
# 1. Often wrongly used:
#
# It is not a measure of risk, but an indication of consistency over time (periods).
#
# Two funds with 20 years track records:
#
#     a. average returns of -5% and vol of 1.
#     b. average returns of 10% and vol of 7.
#
# Which one is "riskier"?

# %%
#Example of two funds with same historical average return, but very different volatilities...
two_funds = pd.read_csv("Two funds.csv")
two_funds
# Out:
#    Year  Fund A  Fund B
# 0  2012       5      10
# 1  2013       5       0
# 2  2014       5      10
# 3  2015       5       0
# 4  2016       5      10
# 5  2017       5       0

# %%
sp_average_std = sp501['Value'].std()
sp_average_std
# Out:
# 19.702879162527395

# %% [markdown]
# Question: can volatility ever be negative, and if so under what circumstances?
# No. The complete absence of volatility is simply 0.

# %% [markdown]
# In investing and therefore in risk analytics, time is always a parameter. Let's see how.
#
# Go to
# https://finance.yahoo.com/quote/^GSPC/history?period1=1348700400&period2=1506466800&interval=1d&filter=history&frequency=1d
# and download the historical prices for the S&P 500, daily and monthly. In this tutorial the date range was September 26 2012-September 26 2017.
#
# I kept here the files' original names.

# %%
sp500_daily = pd.read_csv('GSPC_daily.csv')
sp500_monthly = pd.read_csv('GSPC_monthly.csv')

# %%
sp500_daily.head()
# Out:
#          Date         Open         High          Low        Close  \
# 0  2012-09-26  1441.599976  1441.599976  1430.530029  1433.319946
# 1  2012-09-27  1433.359985  1450.199951  1433.359985  1447.150024
# 2  2012-09-28  1447.130005  1447.130005  1435.599976  1440.670044
# 3  2012-10-01  1440.900024  1457.140015  1440.900024  1444.489990
# 4  2012-10-02  1444.989990  1451.520020  1439.010010  1445.750000
#
#      Adj Close      Volume
# 0  1433.319946  3565380000
# 1  1447.150024  3150330000
# 2  1440.670044  3509230000
# 3  1444.489990  3505080000
# 4  1445.750000  3321790000

# %%
#the shift function allows us to shift all values up or down in a column.

sp500_daily['daily_returns'] = sp500_daily['Adj Close'] / sp500_daily['Adj Close'].shift(1)-1
sp500_daily.head(5)
# Out:
#          Date         Open         High          Low        Close  \
# 0  2012-09-26  1441.599976  1441.599976  1430.530029  1433.319946
# 1  2012-09-27  1433.359985  1450.199951  1433.359985  1447.150024
# 2  2012-09-28  1447.130005  1447.130005  1435.599976  1440.670044
# 3  2012-10-01  1440.900024  1457.140015  1440.900024  1444.489990
# 4  2012-10-02  1444.989990  1451.520020  1439.010010  1445.750000
#
#      Adj Close      Volume  daily_returns
# 0  1433.319946  3565380000            NaN
# 1  1447.150024  3150330000       0.009649
# 2  1440.670044  3509230000      -0.004478
# 3  1444.489990  3505080000       0.002652
# 4  1445.750000  3321790000       0.000872

# %%
sp500_daily_vol = sp500_daily['daily_returns'].std()
sp500_daily_vol_annualized = sp500_daily_vol * math.sqrt(252)
sp500_daily_vol, sp500_daily_vol_annualized
# Out:
# (0.007668116862563054, 0.12172758145513618)

# %%
sp500_monthly.head(5)
# Out:
#          Date         Open         High          Low        Close  \
# 0  2012-09-01         null         null         null         null
# 1  2012-10-01  1440.900024  1470.959961  1403.280029  1412.160034
# 2  2012-11-01  1412.199951  1434.270020  1343.349976  1416.180054
# 3  2012-12-01  1416.339966  1448.000000  1398.109985  1426.189941
# 4  2013-01-01  1426.189941  1509.939941  1426.189941  1498.109985
#
#      Adj Close       Volume
# 0         null         null
# 1  1412.160034  71752320000
# 2  1416.180054  71489310000
# 3  1426.189941  66388180000
# 4  1498.109985  75848510000

# %%
sp500_monthly['Adj Close'] = pd.to_numeric(sp500_monthly['Adj Close'], errors = 'coerce')

# %%
sp500_monthly['monthly_returns'] = sp500_monthly['Adj Close'] / sp500_monthly['Adj Close'].shift(1)-1
sp500_monthly.head(5)
# Out:
#          Date         Open         High          Low        Close  \
# 0  2012-09-01         null         null         null         null
# 1  2012-10-01  1440.900024  1470.959961  1403.280029  1412.160034
# 2  2012-11-01  1412.199951  1434.270020  1343.349976  1416.180054
# 3  2012-12-01  1416.339966  1448.000000  1398.109985  1426.189941
# 4  2013-01-01  1426.189941  1509.939941  1426.189941  1498.109985
#
#      Adj Close       Volume  monthly_returns
# 0          NaN         null              NaN
# 1  1412.160034  71752320000              NaN
# 2  1416.180054  71489310000         0.002847
# 3  1426.189941  66388180000         0.007068
# 4  1498.109985  75848510000         0.050428

# %%
sp500_monthly_vol = sp500_monthly['monthly_returns'].std()
sp500_monthly_vol_annualized = sp500_monthly_vol * math.sqrt(12)
sp500_monthly_vol, sp500_monthly_vol_annualized
# Out:
# (0.02720897718750704, 0.09425466182148945)

# %% [markdown]
# What do we learn from this?
#
# not revaluing your portfolio too often can lead to a low vol strategy
#
# p.s. it can also lead to absolute, uncorrelated returns, especially in times of crisis

# %% [markdown]
# Our statistics are highly time dependant including in terms of inputs

# %% [markdown]
# We are sitting now with a mean that is accompanied by a relatively high volatility.
#
# How do we get a more accurate picture of the long term averages?
#
# Longer rolling returns periods. This smoothes the values over. This is also why some funds prefer basing their performance fees on rolling returns.
#
# Let's smoothe

# %%
sp501["3yr rolling mean"] = sp501['Value'].rolling(window = 3, center=False).mean()
sp501["10yr rolling mean"] = sp501['Value'].rolling(window = 10, center=False).mean()
# Out:
# //anaconda/lib/python3.6/site-packages/ipykernel/__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':
# //anaconda/lib/python3.6/site-packages/ipykernel/__main__.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   from ipykernel import kernelapp as app

# %%
sp501.set_index('Year').plot()

# %%
sp501
# Out:
#     Year  Value  3yr rolling mean  10yr rolling mean
# 0   1928  43.81               NaN                NaN
# 1   1929  -8.30               NaN                NaN
# 2   1930 -25.12          3.463333                NaN
# 3   1931 -43.84        -25.753333                NaN
# 4   1932  -8.64        -25.866667                NaN
# 5   1933  49.98         -0.833333                NaN
# 6   1934  -1.19         13.383333                NaN
# 7   1935  46.74         31.843333                NaN
# 8   1936  31.94         25.830000                NaN
# 9   1937 -35.34         14.446667              5.004
# 10  1938  29.28          8.626667              3.551
# 11  1939  -1.10         -2.386667              4.271
# 12  1940 -10.67          5.836667              5.716
# 13  1941 -12.77         -8.180000              8.823
# 14  1942  19.17         -1.423333             11.604
# 15  1943  25.06         10.486667              9.112
# 16  1944  19.03         21.086667             11.134
# 17  1945  35.82         26.636667             10.042
# 18  1946  -8.43         15.473333              6.005
# 19  1947   5.20         10.863333             10.059
# 20  1948   5.70          0.823333              7.701
# 21  1949  18.30          9.733333              9.641
# 22  1950  30.81         18.270000             13.789
# 23  1951  23.68         24.263333             17.434
# 24  1952  18.15         24.213333             17.332
# 25  1953  -1.21         13.540000             14.705
# 26  1954  52.56         23.166667             18.058
# 27  1955  32.60         27.983333             17.736
# 28  1956   7.44         30.866667             19.323
# 29  1957 -10.46          9.860000             17.757
# ..   ...    ...               ...                ...
# 59  1987   5.81         18.513333             15.652
# 60  1988  16.54         13.613333             16.655
# 61  1989  31.48         17.943333             17.951
# 62  1990  -3.06         14.986667             14.471
# 63  1991  30.23         19.550000             17.964
# 64  1992   7.49         11.553333             16.671
# 65  1993   9.97         15.896667             15.434
# 66  1994   1.33          6.263333             14.952
# 67  1995  37.20         16.166667             15.548
# 68  1996  22.68         20.403333             15.967
# 69  1997  33.10         30.993333             18.696
# 70  1998  28.34         28.040000             19.876
# 71  1999  20.89         27.443333             18.817
# 72  2000  -9.03         13.400000             18.220
# 73  2001 -11.85          0.003333             14.012
# 74  2002 -21.97        -14.283333             11.066
# 75  2003  28.36         -1.820000             12.905
# 76  2004  10.74          5.710000             13.846
# 77  2005   4.83         14.643333             10.609
# 78  2006  15.61         10.393333              9.902
# 79  2007   5.48          8.640000              7.140
# 80  2008 -36.55         -5.153333              0.651
# 81  2009  25.94         -1.710000              1.156
# 82  2010  14.82          1.403333              3.541
# 83  2011   2.10         14.286667              4.936
# 84  2012  15.89         10.936667              8.722
# 85  2013  32.15         16.713333              9.101
# 86  2014  13.52         20.520000              9.379
# 87  2015   1.36         15.676667              9.032
# 88  2016  11.74          8.873333              8.645
#
# [89 rows x 4 columns]

# %%
sp501['3yr rolling mean'].max()
# Out:
# 31.84333333333333

# %%
sp501['10yr rolling mean'].max()
# Out:
# 21.559000000000001

# %% [markdown]
# Second issue: The standard deviation assumes normality of the distribution. What is a normal distribution?
#
# About 68% of the observed returns will be within a range of one standard deviation above and
# below the mean return.
#
# ■ Approximately 90% of returns within ±1.65 standard deviations.
#
# ■ Approximately 95% of returns within ±2 standard deviations.
#
# ■ Almost all returns within ±3 standard deviations.
#
# Are historical returns of S&P500 normally distributed?

# %%
sns.distplot(sp501['Value'])

# %%
#Quick tip: If it is normally distributed, the mean and the median should be the same.
sp501['Value'].mean(), sp501['Value'].median()
# Out:
# (11.415842696629218, 13.52)

# %% [markdown]
# What allows us to describe the shape of a distribution more precisely?
#
# The third and fourth moments of a distribution. Skewness and Kurtosis.
#
# Skewness (3rd moment): the degree of asymmetry of a distribution around its mean. Negative or left skewness means an asymmetric left tail that extends more towards negative values than its right counterparty. And vice-versa. In a negatively skewed distribution, the mean will be lower than the median, and the standard deviation will underestimate the proportion of returns below the mean and overestimate the proportion of returns above the mean.
#
# Kurtosis (4th moment): degree of peakness of a distribution. Normal distribution is 3. A lower value indicates a flatter distribution or platykurtic and a higher value a more peaked, or leptokurtic distribution. A higher value implies more returns closer to the mean than for the normal distribution, and therefore also fatter tails i.e. more high values in the tails than we would otherwise expect.
#
# ! Skewness and kurtosis are not measured in units of return.

# %%
from IPython.display import Image
from IPython.core.display import HTML 
Image("Two_distributions.png")

# %% [markdown]
# Many thanks to Con Keating for kindly providing this illustration.
#
# Keating, Con, and William Shadwick. An Introduction to Omega. The Finance Development Centre, 2002, An Introduction to Omega.

# %% [markdown]
# Skewness
#
# Formula for calculating the skewness:
# $\sum (\frac {x_i - \overline x}{stdev(x_i)}) ^ 3 * \frac{1}{N}$

# %%
skewness = sp501['Value'].skew()
skewness
# Out:
# -0.40401800741280103

# %% [markdown]
# Negative skewness? What do we do now??

# %% [markdown]
# Kurtosis: same formula as skewness, but we raise to the power of 4 instead of 3
#
# Formula for calculating the skewness:
# $\sum (\frac {x_i - \overline x}{stdev(x_i)}) ^ 4 * \frac{1}{N}$

# %%
kurtosis = sp501['Value'].kurtosis()
kurtosis
# Out:
# 0.088679683721088143

# %% [markdown]
# !The kurtosis function in pandas returns the excess kurtosis actually, not the kurtosis itself.
# In this case, we have a slightly higher kurtosis and therefore fat tails i.e. frequency of outcomes in the tails, at the extremes, is higher than we would expect based on a normal distribution.

# %% [markdown]
# How do we test for both/for normality?
#
# Jarque-Bera test.
#
# Named after Carlos Jarque and Anil Bera.
#
# Compares skewness and kurtosis to what would be expected for a normal distribution i.e. a skewness of 0 and an excess kurtosis of 0.
# Deviation from either one will increase its value. If greater than 6, usually a sign that distribution is not normal.
#
# Formula:
#
# $(skewness^2 + \frac {excess \ kurtosis^2}{4}) * \frac{N}{6}$

# %%
#scipy offers a jarque bera test function
#Note: this test is not always reliable if there are few observations.
scipy.stats.jarque_bera(sp501['Value'])
# Out:
# (2.3410325018531082, 0.31020675539609432)

# %% [markdown]
# What can we conclude?

# %% [markdown]
# # Risk
# The financial crisis and ensuing recession from a risk perspective
#
# The "Our risk models were wrong" and "We did not understand risk" arguments
#
# Risk analytics is impossible in a probabilistic universe?
#
# Risk analysts/modelling experts are palm readers?
#
# I believe this to be an oversimplification/wrong.
#
# You misestimate risk by using the wrong distribution, or the wrong value for your stdev. The problem is simple - the solution may not be.
#
# First of all, what is risk? Several definitions of risk
# 1. The risk of losing money i.e. absolute risk
# 2. The risk of not achieving a minimal return i.e. internal relative risk
# 3. The risk of deviating from a benchmark too much i.e. external relative risk
#
# Questions we are trying to answer:
#
# How much risk does the portfolio manager take to achieve a certain return?
#
# How much uncertainty surrounds our expected return from this portfolio?
#
# Volatility/Return relationship. See Ibbotson Associates research on these.
#
# Risk measurement vs risk management.
#
# Measures we will review here:
#
# Absolute risk: dev; MAR
#
# Relative risk: correlation; Sharpe; Sortino; Information Ratio

# %% [markdown]
# Some of the issues with the stdev:
#
# 1. Two funds can have the same historical returns with widely different standard deviations. A fund can consistently lose money and have a significantly lower standard deviation than a fund annualizing high returns.
# 2. The standard deviation is calculated around the mean of its own distribution i.e. the historical mean of returns for the model/fund in our case.
# 3. Units
# 4. The standard deviation places the same emphasis on upside and downside deviations from the mean. We are usually only wary of downside deviation, while warmly welcoming the upside one.

# %% [markdown]
# Question: can you compare two funds based on the standard deviation of their returns?
# No. You need a dimensionless measure to compare them, given that each stdev is calculated in relation to the mean of its own distribution.
#
# Standardization
#
# The coefficient of variation

# %%
coef_variation = sp501['Value'].std()/sp501['Value'].mean()
coef_variation
# Out:
# 1.7259241990383338

# %% [markdown]
# Partial moments - measure part of the distribution
#
# A lower partial moment: the semideviation. The stdev of returns that fall below the mean return.
#
# $ semideviation = \sqrt(\frac{\sum(x_i - \overline x) ^2 where (x_i < \overline x)}{N})$

# %%
mean = sp501['Value'].mean()
def semidev(x):
    if x < mean:
        return x
    else:
        return 0

# %%
sp501['Negative deviation'] = sp501['Value'].apply(semidev)

# %%
sp501
# Out:
#     Year  Value  3yr rolling mean  10yr rolling mean  Negative deviation
# 0   1928  43.81               NaN                NaN                0.00
# 1   1929  -8.30               NaN                NaN               -8.30
# 2   1930 -25.12          3.463333                NaN              -25.12
# 3   1931 -43.84        -25.753333                NaN              -43.84
# 4   1932  -8.64        -25.866667                NaN               -8.64
# 5   1933  49.98         -0.833333                NaN                0.00
# 6   1934  -1.19         13.383333                NaN               -1.19
# 7   1935  46.74         31.843333                NaN                0.00
# 8   1936  31.94         25.830000                NaN                0.00
# 9   1937 -35.34         14.446667              5.004              -35.34
# 10  1938  29.28          8.626667              3.551                0.00
# 11  1939  -1.10         -2.386667              4.271               -1.10
# 12  1940 -10.67          5.836667              5.716              -10.67
# 13  1941 -12.77         -8.180000              8.823              -12.77
# 14  1942  19.17         -1.423333             11.604                0.00
# 15  1943  25.06         10.486667              9.112                0.00
# 16  1944  19.03         21.086667             11.134                0.00
# 17  1945  35.82         26.636667             10.042                0.00
# 18  1946  -8.43         15.473333              6.005               -8.43
# 19  1947   5.20         10.863333             10.059                5.20
# 20  1948   5.70          0.823333              7.701                5.70
# 21  1949  18.30          9.733333              9.641                0.00
# 22  1950  30.81         18.270000             13.789                0.00
# 23  1951  23.68         24.263333             17.434                0.00
# 24  1952  18.15         24.213333             17.332                0.00
# 25  1953  -1.21         13.540000             14.705               -1.21
# 26  1954  52.56         23.166667             18.058                0.00
# 27  1955  32.60         27.983333             17.736                0.00
# 28  1956   7.44         30.866667             19.323                7.44
# 29  1957 -10.46          9.860000             17.757              -10.46
# ..   ...    ...               ...                ...                 ...
# 59  1987   5.81         18.513333             15.652                5.81
# 60  1988  16.54         13.613333             16.655                0.00
# 61  1989  31.48         17.943333             17.951                0.00
# 62  1990  -3.06         14.986667             14.471               -3.06
# 63  1991  30.23         19.550000             17.964                0.00
# 64  1992   7.49         11.553333             16.671                7.49
# 65  1993   9.97         15.896667             15.434                9.97
# 66  1994   1.33          6.263333             14.952                1.33
# 67  1995  37.20         16.166667             15.548                0.00
# 68  1996  22.68         20.403333             15.967                0.00
# 69  1997  33.10         30.993333             18.696                0.00
# 70  1998  28.34         28.040000             19.876                0.00
# 71  1999  20.89         27.443333             18.817                0.00
# 72  2000  -9.03         13.400000             18.220               -9.03
# 73  2001 -11.85          0.003333             14.012              -11.85
# 74  2002 -21.97        -14.283333             11.066              -21.97
# 75  2003  28.36         -1.820000             12.905                0.00
# 76  2004  10.74          5.710000             13.846               10.74
# 77  2005   4.83         14.643333             10.609                4.83
# 78  2006  15.61         10.393333              9.902                0.00
# 79  2007   5.48          8.640000              7.140                5.48
# 80  2008 -36.55         -5.153333              0.651              -36.55
# 81  2009  25.94         -1.710000              1.156                0.00
# 82  2010  14.82          1.403333              3.541                0.00
# 83  2011   2.10         14.286667              4.936                2.10
# 84  2012  15.89         10.936667              8.722                0.00
# 85  2013  32.15         16.713333              9.101                0.00
# 86  2014  13.52         20.520000              9.379                0.00
# 87  2015   1.36         15.676667              9.032                1.36
# 88  2016  11.74          8.873333              8.645                0.00
#
# [89 rows x 5 columns]

# %%
def semidev2(x):
    if x != 0:
        return (x - mean)**2
    else:
        return 0

# %%
sp501['semidev2'] = sp501['Negative deviation'].apply(semidev2)
sp501
# Out:
#     Year  Value  3yr rolling mean  10yr rolling mean  Negative deviation  \
# 0   1928  43.81               NaN                NaN                0.00
# 1   1929  -8.30               NaN                NaN               -8.30
# 2   1930 -25.12          3.463333                NaN              -25.12
# 3   1931 -43.84        -25.753333                NaN              -43.84
# 4   1932  -8.64        -25.866667                NaN               -8.64
# 5   1933  49.98         -0.833333                NaN                0.00
# 6   1934  -1.19         13.383333                NaN               -1.19
# 7   1935  46.74         31.843333                NaN                0.00
# 8   1936  31.94         25.830000                NaN                0.00
# 9   1937 -35.34         14.446667              5.004              -35.34
# 10  1938  29.28          8.626667              3.551                0.00
# 11  1939  -1.10         -2.386667              4.271               -1.10
# 12  1940 -10.67          5.836667              5.716              -10.67
# 13  1941 -12.77         -8.180000              8.823              -12.77
# 14  1942  19.17         -1.423333             11.604                0.00
# 15  1943  25.06         10.486667              9.112                0.00
# 16  1944  19.03         21.086667             11.134                0.00
# 17  1945  35.82         26.636667             10.042                0.00
# 18  1946  -8.43         15.473333              6.005               -8.43
# 19  1947   5.20         10.863333             10.059                5.20
# 20  1948   5.70          0.823333              7.701                5.70
# 21  1949  18.30          9.733333              9.641                0.00
# 22  1950  30.81         18.270000             13.789                0.00
# 23  1951  23.68         24.263333             17.434                0.00
# 24  1952  18.15         24.213333             17.332                0.00
# 25  1953  -1.21         13.540000             14.705               -1.21
# 26  1954  52.56         23.166667             18.058                0.00
# 27  1955  32.60         27.983333             17.736                0.00
# 28  1956   7.44         30.866667             19.323                7.44
# 29  1957 -10.46          9.860000             17.757              -10.46
# ..   ...    ...               ...                ...                 ...
# 59  1987   5.81         18.513333             15.652                5.81
# 60  1988  16.54         13.613333             16.655                0.00
# 61  1989  31.48         17.943333             17.951                0.00
# 62  1990  -3.06         14.986667             14.471               -3.06
# 63  1991  30.23         19.550000             17.964                0.00
# 64  1992   7.49         11.553333             16.671                7.49
# 65  1993   9.97         15.896667             15.434                9.97
# 66  1994   1.33          6.263333             14.952                1.33
# 67  1995  37.20         16.166667             15.548                0.00
# 68  1996  22.68         20.403333             15.967                0.00
# 69  1997  33.10         30.993333             18.696                0.00
# 70  1998  28.34         28.040000             19.876                0.00
# 71  1999  20.89         27.443333             18.817                0.00
# 72  2000  -9.03         13.400000             18.220               -9.03
# 73  2001 -11.85          0.003333             14.012              -11.85
# 74  2002 -21.97        -14.283333             11.066              -21.97
# 75  2003  28.36         -1.820000             12.905                0.00
# 76  2004  10.74          5.710000             13.846               10.74
# 77  2005   4.83         14.643333             10.609                4.83
# 78  2006  15.61         10.393333              9.902                0.00
# 79  2007   5.48          8.640000              7.140                5.48
# 80  2008 -36.55         -5.153333              0.651              -36.55
# 81  2009  25.94         -1.710000              1.156                0.00
# 82  2010  14.82          1.403333              3.541                0.00
# 83  2011   2.10         14.286667              4.936                2.10
# 84  2012  15.89         10.936667              8.722                0.00
# 85  2013  32.15         16.713333              9.101                0.00
# 86  2014  13.52         20.520000              9.379                0.00
# 87  2015   1.36         15.676667              9.032                1.36
# 88  2016  11.74          8.873333              8.645                0.00
#
#        semidev2
# 0      0.000000
# 1    388.714453
# 2   1334.867802
# 3   3053.208152
# 4    402.236826
# 5      0.000000
# 6    158.907270
# 7      0.000000
# 8      0.000000
# 9   2186.108826
# 10     0.000000
# 11   156.646318
# 12   487.784448
# 13   584.954987
# 14     0.000000
# 15     0.000000
# 16     0.000000
# 17     0.000000
# 18   393.857472
# 19    38.636700
# 20    32.670858
# 21     0.000000
# 22     0.000000
# 23     0.000000
# 24     0.000000
# 25   159.411904
# 26     0.000000
# 27     0.000000
# 28    15.807325
# 29   478.552494
# ..          ...
# 59    31.425472
# 60     0.000000
# 61     0.000000
# 62   209.550022
# 63     0.000000
# 64    15.412241
# 65     2.090461
# 66   101.724223
# 67     0.000000
# 68     0.000000
# 69     0.000000
# 70     0.000000
# 71     0.000000
# 72   418.032484
# 73   541.299436
# 74  1114.614493
# 75     0.000000
# 76     0.456763
# 77    43.373324
# 78     0.000000
# 79    35.234229
# 80  2300.722066
# 81     0.000000
# 82     0.000000
# 83    86.784925
# 84     0.000000
# 85     0.000000
# 86     0.000000
# 87   101.119972
# 88     0.000000
#
# [89 rows x 6 columns]

# %%
semideviation = math.sqrt(sp501['semidev2'].sum()/len(sp501))
semideviation
# Out:
# 14.61720072842248

# %% [markdown]
# Question: can the semideviation and standard deviation be the same?

# %% [markdown]
# Issue mentioned: standard deviation and semideviation are both relative to their own means.
#
# What about deviation from an absolute return?
#
# Downside measures that are not calculated around the historical mean are particularly helpful and informative when we don't deal with a normal distribution.
#
# Concept of MAR.
#
# Shortfall risk: percentage of returns that fall below target return
#
# $shortfall= \frac{number \ of \ returns < target \ return}{total \ number \ of \ returns}$

# %%
shortfall_risk = len([x for x in sp501['Value'] if x < 5])/len(sp501)*100
shortfall_risk
# Out:
# 33.70786516853933

# %% [markdown]
# This tells us how often it happens. But what about the magnitude of the downside deviation when it does happen?

# %% [markdown]
# Expected downside value
#
# $expected \ downside = \frac{\sum x_i - target \ return \ where \ x_i < target \ return}{N}$

# %%
expected_downside_value = sum([(x-5) for x in sp501['Value'] if x < 5])/len(sp501)
expected_downside_value
# Out:
# -5.2238202247191019

# %% [markdown]
# When the return fell below our target, it fell below by an average of 5.22%.

# %% [markdown]
# ## Now looking at relative risk.
# Relative to what?
#
# Concept of benchmark
#
# > Practitioners have come to accept that a peer group universe does not fulfill all of the requirements for a good
# > measure of relative performance. Jeffrey Bailey set out the criteria of a good performance comparison benchmark,
# > which is “unambiguous, investable, measurable, appropriate, and specified in advance.”
#
# > Jeffrey Bailey
#
# Overall, two types of benchmarking:
# 1. To a standard i.e. index
# 2. To your peer group #here in some cases I disagree with Bailey. Your peer group will rarely correspond to his excellent definition of a benchmark, but it makes for a great benchmark nonetheless when it comes to assessing yourself/another portfolio. For more niche strategies without public benchmarks in particular, this is a great benchmark to provide context to someone's performance.
#
# Significantly easier/more standardized in some asset classes than others for example.
#
# "But, what I do is so special and unique and wonderful that I don't have a benchmark..."
#
# Silly.

# %% [markdown]
# Download monthly returns for period 2015-2016 from Barclay Hedge Fund Index:
#
# https://www.barclayhedge.com/research/indices/ghs/Hedge_Fund_Index.html
#
# Many thanks to Barclay Hedge for making this data publicly available.
#
# Download 1m US Treasury rate from the St Louis Fed website:
# https://fred.stlouisfed.org/series/DGS1MO
#
# The data is daily, take the monthly value as the value on the first available day of each month (you can also do the last day of the previous month).
#
# Board of Governors of the Federal Reserve System (US), 1-Month Treasury Constant Maturity Rate [DGS1MO], retrieved from FRED, Federal Reserve Bank of St. Louis; https://fred.stlouisfed.org/series/DGS1MO, October 15, 2017.
#
# copy monthly returns for S&P 500 for those two years in the same file as the Barclay Hedge Fund Index and the 1m US Treasury

# %%
returns = pd.read_csv("Hedge Fund Index vs SP 500 returns.csv")
returns.head(24)
# Out:
#    Unnamed: 0  Popular hedge fund index  S&P 500   1m Treasury Yield
# 0    30-01-15                     -0.10    -3.10                0.02
# 1    28-02-15                      2.20     5.49                0.01
# 2    30-03-15                      0.42    -1.74                0.02
# 3    30-04-15                      1.08     0.85                0.02
# 4    30-05-15                      0.81     1.05                0.00
# 5    30-06-15                     -1.09    -2.10                0.02
# 6    30-07-15                     -0.55     1.97                0.01
# 7    30-08-15                     -2.50    -6.26                0.03
# 8    30-09-15                     -1.69    -2.64                0.01
# 9    30-10-15                      2.22     8.30                0.00
# 10   30-11-15                      0.22     0.05                0.01
# 11   30-12-15                     -0.86    -1.75                0.19
# 12   30-01-16                     -2.99    -5.07                0.17
# 13   28-02-16                     -0.35    -0.41                0.19
# 14   30-03-16                      2.45     6.60                0.29
# 15   30-04-16                      1.03     0.27                0.20
# 16   30-05-16                      0.62     1.53                0.11
# 17   30-06-16                     -0.04     0.09                0.27
# 18   30-07-16                      2.04     3.56                0.24
# 19   30-08-16                      0.73    -0.12                0.20
# 20   30-09-16                      0.89    -0.12                0.27
# 21   30-10-16                     -0.31    -1.94                0.25
# 22   30-11-16                      0.82     3.42                0.24
# 23   30-12-16                      1.14     1.82                0.32

# %%
returns.set_index(returns['Unnamed: 0'], inplace = True)
returns.columns
# Out:
# Index(['Unnamed: 0', 'Popular hedge fund index', 'S&P 500',
#        ' 1m Treasury Yield'],
#       dtype='object')

# %%
returns.drop('Unnamed: 0', axis = 1, inplace=True)

# %%
returns
# Out:
#             Popular hedge fund index  S&P 500   1m Treasury Yield
# Unnamed: 0
# 30-01-15                       -0.10    -3.10                0.02
# 28-02-15                        2.20     5.49                0.01
# 30-03-15                        0.42    -1.74                0.02
# 30-04-15                        1.08     0.85                0.02
# 30-05-15                        0.81     1.05                0.00
# 30-06-15                       -1.09    -2.10                0.02
# 30-07-15                       -0.55     1.97                0.01
# 30-08-15                       -2.50    -6.26                0.03
# 30-09-15                       -1.69    -2.64                0.01
# 30-10-15                        2.22     8.30                0.00
# 30-11-15                        0.22     0.05                0.01
# 30-12-15                       -0.86    -1.75                0.19
# 30-01-16                       -2.99    -5.07                0.17
# 28-02-16                       -0.35    -0.41                0.19
# 30-03-16                        2.45     6.60                0.29
# 30-04-16                        1.03     0.27                0.20
# 30-05-16                        0.62     1.53                0.11
# 30-06-16                       -0.04     0.09                0.27
# 30-07-16                        2.04     3.56                0.24
# 30-08-16                        0.73    -0.12                0.20
# 30-09-16                        0.89    -0.12                0.27
# 30-10-16                       -0.31    -1.94                0.25
# 30-11-16                        0.82     3.42                0.24
# 30-12-16                        1.14     1.82                0.32

# %%
#let's visualize the two return streams, keeping an eye open for association
returns_copy = returns.copy()
returns_copy.columns = ["hedgeFundIndex", "SP500", "1m Treasury Yield"]
sns.regplot(x='S&P 500', y = 'Popular hedge fund index', data = returns)

# %% [markdown]
# What does this dispersion tell us? How else could it look?

# %% [markdown]
# Covariance. Powerful statistical measure but of limited use by itself as difficult to interpret in a meaningful way.
# Note: a covariance of 0 would indicate no relationship between the two return streams that we are comparing over the period.
#
# What is correlation?
#
# Amount by which two return streams vary together. Correlation captures the direction and magnitude of this variation.
#
# Formula:
#
# $Correlation \ = \ \frac {covariance}{stdev \ (fund \ returns) * stdev \ (benchmark \ returns)}$

# %%
correlation = returns.corr()
correlation
# Out:
#                           Popular hedge fund index   S&P 500  \
# Popular hedge fund index                  1.000000  0.877012
# S&P 500                                   0.877012  1.000000
#  1m Treasury Yield                        0.195101  0.119207
#
#                            1m Treasury Yield
# Popular hedge fund index            0.195101
# S&P 500                             0.119207
#  1m Treasury Yield                  1.000000

# %% [markdown]
# Issues with correlation as a measure:
#
# Easy to interpret at its extremes, but much fuzzier when the value is somewhere in the middle of the possible range.
#
# By the way, what is its range of possible values?
#
# What is the rule of thumb for being "uncorrelated" in applied investing?

# %%
#Coefficient of determination
#square of the correlation coefficient
#easier to interpret: proportion of portfolio returns that can be explained by variability in benchmark returns
r_squared = 0.877012**2
r_squared
# Out:
# 0.769150048144

# %% [markdown]
# How do you interpret it?
#
# What is the range of its possible values?
# 0 to 1.
#
# What is the coefficient of nondetermination?
# This is simply 1-coefficient of determination.

# %% [markdown]
# ## Alpha and beta
#
# What is alpha?
#
# Alpha remains an elusive concept.
#
# Identifiable, in a strict sense, via a classic linear regression analysis.
# Average fund return = alpha + beta * average benchmark return
#
# What is beta?
#
# Magnitude of variability in fund returns related to variability in benchmark returns. A measure of co-movement, not of absolute movement i.e. volatility.
#
# NASDAQ definition:
# "The measure of an asset's risk in relation to the market (for example, the S&P500) or to an alternative benchmark or factors. Roughly speaking, a security with a beta of 1.5, will have move, on average, 1.5 times the market return. [More precisely, that stock's excess return (over and above a short-term money market rate) is expected to move 1.5 times the market excess return).] According to asset pricing theory, beta represents the type of risk, systematic risk, that cannot be diversified away."
#
# A beta below 1 can indicate an asset with a lower volatility than the market (bonds), or with a significant but uncorrelated volatility (gold). A beta greater than 1 tends to indicate an asset that is both volatile and moves with the market.

# %%
formula = "hedgeFundIndex ~ SP500"
test1 = smf.ols(formula, data = returns_copy).fit()
print(test1.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:         hedgeFundIndex   R-squared:                       0.769
# Model:                            OLS   Adj. R-squared:                  0.759
# Method:                 Least Squares   F-statistic:                     73.30
# Date:                Sat, 11 Nov 2017   Prob (F-statistic):           1.88e-08
# Time:                        12:36:41   Log-Likelihood:                -24.173
# No. Observations:                  24   AIC:                             52.35
# Df Residuals:                      22   BIC:                             54.70
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.1115      0.142      0.784      0.441      -0.184       0.407
# SP500          0.3603      0.042      8.562      0.000       0.273       0.448
# ==============================================================================
# Omnibus:                        1.292   Durbin-Watson:                   1.062
# Prob(Omnibus):                  0.524   Jarque-Bera (JB):                1.152
# Skew:                          -0.384   Prob(JB):                        0.562
# Kurtosis:                       2.250   Cond. No.                         3.41
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# What does this beta tell us?
# Is it high or low?
#
# !A higher beta implies that the fund has taken on more benchmark relative risk.
# How do we read the alpha and beta here?
#
# Why bother with the beta if we have the correlation already?
#
# Question: if a fund has a very high beta, does that mean that its returns are roughly similar to those of the benchmark?
#
# What does a beta of 1 mean?

# %%
#Alpha
alpha = 0.1115
annualized_alpha = (1+alpha)**12 - 1
annualized_alpha
# Out:
# 2.555605787383672

# %% [markdown]
# Check the following, from two leading industry sources, to get an idea of the multitude of definitions available in the industry for the same thing
#
# https://www.evestment.com/resources/investment-statistics-guide/relative-risk-adjusted-return-measures-and-annualized-alpha/
#
# https://admainnew.morningstar.com/webhelp/glossary_definitions/mutual_fund/glossary_all_Alpha.html

# %% [markdown]
# An aside through the long only world
#
# Tracking risk indicates how much the portfolio's returns deviate from the benchmark's returns over time.
#
# $tracking \ risk = stdev(fund \ returns)* \sqrt(1-(correlation)^2)$

# %%
tracking_risk = returns['Popular hedge fund index'].std() * math.sqrt(1-((pearsonr(returns['Popular hedge fund index'], returns['S&P 500']))[0])**2)
tracking_risk
# Out:
# 0.6767632235864324

# %%
#Annualized tracking risk
tracking_risk * math.sqrt(12)
# Out:
# 2.3443765758915935

# %% [markdown]
# When and why bother with tracking risk?
#
# Degree of difference in fund returns and benchmarl returns over time.
#
# Units?
#
# Expressed in units of return.

# %% [markdown]
# # Moving on to relative risk/return measures

# %% [markdown]
# Concept: systematic vs unsystematic risk.
#
# The Sharpe ratio, a risk adjusted measure of excess return
#
# Instead of only measuring return, it measures excess return per unit of deviation of an investment's returns
#
# Key concept: with summary metrics in general you are trying to capture more (relevant) information in your metric
#
# Formula:
#
# $Sharpe = \frac{annual \ mean \ fund \ return - annual \ mean \ risk \ free \ return}{annualized \ stdev}$
#
# What is a risk free investment? How to choose a proxy for it here?

# %%
sharpe = (returns_copy['hedgeFundIndex'].mean() - returns_copy['1m Treasury Yield'].mean()) / (returns_copy['hedgeFundIndex'].std())
sharpe * math.sqrt(12)
# Out:
# 0.3176649575664517

# %% [markdown]
# !attention - I kept with our monthly dataset, and while our returns are monthly here, per the formula we should have used the annual means in the Sharpe and not the monthly ones.
#
# I quickly annualized here following a standard annualization technique but this only holds in special circumstances
#
# See: http://www.edge-fund.com/Lo02.pdf

# %% [markdown]
# What do you think of this Sharpe ratio?

# %% [markdown]
# What do you think of its two major drawbacks?
#
# 1. Penalizes upside and downside deviation equally. Few of us will be upset over upside deviation, right?
#
# 2. If you were trying to increase your Sharpe, how would you do it? Hint: look at the formula carefully.
# Second hint: arithmetic returns in a portfolio are additive, while volatility is sub additive\*. Third hint: the numerator grows linearly while the denominator grows hyperbolically.
#
# *to read more on this, see Dan diBartolomeo (2013).

# %% [markdown]
# What if instead of returns to absolute risk, we want to look at returns relative to systematic/market risk?
#
# We use beta as a proxy of market risk: the Treynor ratio. Instead of using the stdev in the denominator, as with the Sharpe ratio, we use beta i.e. market risk.
#
# Formula:
# $Treynor = \frac{mean \ fund \ return - mean \ risk \ free \ return}{beta}$

# %%
treynor = (returns_copy['hedgeFundIndex'].mean() - returns_copy['SP500'].mean()) / 0.36
treynor
# Out:
# -0.412037037037037

# %% [markdown]
# A harsher measure of risk adjusted return: the Sortino ratio
#
# created by Dr Frank Sortino of the Pension Research Institute
#
# a modification of sharpe ratio: downside deviation as denominator and target return subtracted in numerator
#
# Interpretation: excess return to downside risk
#
# $Sortino = \frac{(mean \ fund \ return - target \ return) * P}{\sqrt \frac {\sum (fund \ return - T) ^2 if \ fund \ return < T}{N}* \sqrt P}$

# %%
t = 1.1
def sortino_step_1(x):
    if x < t:
        return x
    else: 
        return 0

# %%
returns_copy['sortino_step_1'] = returns_copy['hedgeFundIndex'].apply(sortino_step_1)

# %%
def sortino_step_2(x):
    if x != 0:
        return (x-t) ** 2
    else:
        return 0

# %%
returns_copy['sortino_step_2'] = returns_copy['sortino_step_1'].apply(sortino_step_2)
returns_copy['sortino_step_2']
# Out:
# Unnamed: 0
# 30-01-15     1.4400
# 28-02-15     0.0000
# 30-03-15     0.4624
# 30-04-15     0.0004
# 30-05-15     0.0841
# 30-06-15     4.7961
# 30-07-15     2.7225
# 30-08-15    12.9600
# 30-09-15     7.7841
# 30-10-15     0.0000
# 30-11-15     0.7744
# 30-12-15     3.8416
# 30-01-16    16.7281
# 28-02-16     2.1025
# 30-03-16     0.0000
# 30-04-16     0.0049
# 30-05-16     0.2304
# 30-06-16     1.2996
# 30-07-16     0.0000
# 30-08-16     0.1369
# 30-09-16     0.0441
# 30-10-16     1.9881
# 30-11-16     0.0784
# 30-12-16     0.0000
# Name: sortino_step_2, dtype: float64

# %%
sortino = ((returns_copy['hedgeFundIndex'].mean() - t) * 12) / (math.sqrt(returns_copy['sortino_step_2'].sum()/len(returns_copy)) * math.sqrt(12))
sortino
# Out:
# -1.8849430134045686

# %% [markdown]
# Note: if you are working already with annual returns, simply remove the multiplication by 12 in the numerator, and the multiplication by the square root of 12 in the denominator.
# Red Rock also provides very good discussions of both the Sortino calculation, and the Sharpe vs Sortino differences.
# http://www.redrockcapital.com/ResearchWhitePapers.html

# %% [markdown]
# As a rule of thumb, when is Sortino higher than Sharpe and vice versa?

# %% [markdown]
# Information ratio
#
# Active return divided by tracking error
#
# The benchmark linked return relative to benchmark linked risk
#
# Formula:
#
# $Annualized \ IR = \frac{ \frac{\sum(fund \ return_i - benchmark \ return_i)}{N} * \sqrt P}{stdev(fund \ return \ i - market \ return \ i) * \sqrt P}$

# %%
ir = ((returns_copy['hedgeFundIndex'] - returns_copy['SP500']).sum()/len(returns_copy) * math.sqrt(12)) / ((returns_copy['hedgeFundIndex'] - returns_copy['SP500']).std()*math.sqrt(12))
ir
# Out:
# -0.06462367033338945

# %% [markdown]
# Next step - something few people undertake. Test of significance of such a result.
#
# t statistic of value added - was it significant or not?
#
# based on statistical hypothesis test
#
# null hypothesis
#
# alternative hypothesis

# %% [markdown]
# How is the information ratio read?
# What does a negative information ratio mean?

# %% [markdown]
# $t \ statistic \ of \ value \ added = \frac{Average (fund \ return - benchmark \ return)}{stdev \ of \ (average \ fund \ return - average \ benchmark \ return) / \sqrt N}$

# %%
t_statistic = ((returns_copy['hedgeFundIndex'] - returns_copy['SP500']).mean())/((returns_copy['hedgeFundIndex'] - returns_copy['SP500']).std() / math.sqrt(len(returns_copy)))
t_statistic
# Out:
# -0.316590035245278

# %% [markdown]
# Can the t value be negative?
# What do we do with this?

# %% [markdown]
# ## Efficiency, skill, and attribution
#
# Mean PnL
#
# Mean Hold
#
# Batting average
#
# Win/Loss ratio

# %%
#the following sections use data from a previous live model
#Many thanks to Clarus Risk for providing this data.

pnl = pd.read_csv("PnL_20170831.csv")
pnl.head()
len(pnl)
# Out:
# 20

# %%
pnl = pnl.iloc[:, 0:9]
pnl.head()
# Out:
#                                   Position  Days    PnL
# 0                      AALBERTS INDUSTRIES    32   0.80
# 1                      AALBERTS INDUSTRIES     9 -16.00
# 2                  ABBOTT LABORATORIES CMN    45   8.28
# 3                        ACCENTURE PLC CMN    21  -5.57
# 4  ACS ACTIVIDADES DE CONST.Y SERVICIOS SA    30  12.14

# %%
pnl['Days'].describe()
# Out:
# count    20.000000
# mean     23.150000
# std      18.221661
# min       2.000000
# 25%      10.000000
# 50%      17.000000
# 75%      30.500000
# max      65.000000
# Name: Days, dtype: float64

# %%
#Average holding period (days)
pnl['Days'].mean()
# Out:
# 23.15

# %%
#Mean PnL (%)
pnl['PnL'].mean()
# Out:
# 4.956

# %% [markdown]
# Now let's calculate the batting average
#
# Why bother with the BA and the WL ratio?
#
# BA: the number of investments that have achieved a positive PnL, versus the total number of investments made. Similar to sports.
#
# WL ratio: the ratio between how well positions with a positive PnL performed, vs how badly positions with a negative PnL performeed, in average.
#
# BA is an indicator of a fund's research and investment analysis skills.
# WL ratio is an indicator of a fund's portfolio construction/management skills i.e. how it manages its winning and losing positiong.
#
# !Unlike most investment statistics, these can be meaningfully compared across strategies, asset classes, and funds.
#
# !Novus has found that BA and WL ratio are more persistent statistics than most others regarding a fund's performance profile, and they attribute this to their focus on the nature of the investment process itself. They explain this as most return analysis statistics are a function of returns, while the BA/WL are drivers of returns. As such, they are less dependant on exogenous factors than returns.

# %%
def ba(x):
    if x > 0:
        return "True"
    else:
        return "False"
pnl['pnl > 0'] = pnl['PnL'].apply(ba)
pnl.head(10)
# Out:
#                                          Position  Days     PnL pnl > 0
# 0                             AALBERTS INDUSTRIES    32    0.80    True
# 1                             AALBERTS INDUSTRIES     9  -16.00   False
# 2                         ABBOTT LABORATORIES CMN    45    8.28    True
# 3                               ACCENTURE PLC CMN    21   -5.57   False
# 4         ACS ACTIVIDADES DE CONST.Y SERVICIOS SA    30   12.14    True
# 5  ACS ACTIVIDADES DE CONST.Y SERVICIOS SA RIGHTS    13  100.00    True
# 6                               ACUITY BRANDS INC    65   -3.01   False
# 7                                       ADECCO SA    13  -12.16   False
# 8                               ADOBE SYSTEMS INC    15    0.16    True
# 9                                      AIRGAS INC     2  -12.25   False

# %%
batting_average = len(pnl[pnl['pnl > 0'] == "True"]) / len(pnl) * 100
batting_average
# Out:
# 55.00000000000001

# %%
#now let's get to W/L ratio
def positive_pnl(x):
    if x >=0:
        return x
    else:
        return 0
def negative_pnl(x):
    if x < 0:
        return abs(x)
    else:
        return 0

# %%
pnl['positive_PnL'] = pnl['PnL'].apply(positive_pnl)
pnl['negative_PnL'] = pnl['PnL'].apply(negative_pnl)
pnl.head()
# Out:
#                                   Position  Days    PnL pnl > 0  positive_PnL  \
# 0                      AALBERTS INDUSTRIES    32   0.80    True          0.80
# 1                      AALBERTS INDUSTRIES     9 -16.00   False          0.00
# 2                  ABBOTT LABORATORIES CMN    45   8.28    True          8.28
# 3                        ACCENTURE PLC CMN    21  -5.57   False          0.00
# 4  ACS ACTIVIDADES DE CONST.Y SERVICIOS SA    30  12.14    True         12.14
#
#    negative_PnL
# 0          0.00
# 1         16.00
# 2          0.00
# 3          5.57
# 4          0.00

# %%
#Note: when calculating the means here, we need to exclude from the count the rows where we have 0 as a value
win_loss_ratio = pnl[pnl['positive_PnL'] != 0]['positive_PnL'].mean() / pnl[pnl['negative_PnL'] != 0]['negative_PnL'].mean()
win_loss_ratio
# Out:
# 1.9197599466548123

# %% [markdown]
# ## Performance attribution (Style and Brinson attribution)
#
# >"Many funds that employ multiple managers focus their attention solely on the problem of >manager selection. Only now are some funds beginning to realize that they must develop a >method for delineating responsibility and measuring the performance contribution of those >activities that compose the investment management process - investment policy, market timing >and security selection. The relative importance of policy, timing and selection can be >determined only if we have a clear and relevant method of attributing returns to these >factors."
#
# >Brinson, Hood and Beebower (1995)
#
# Here we break down a portfolio/model/manager's performance in order to understand how it was achieved. What the impact of security selection? Did it add positively to the total performance? What was the impact of sector allocation? Did it contribute positively?
#
# ■ What was the manager's relative skill in selecting securities?
#
# ■ What was the manager's relative skill in selecting market segments?
#
# ■ How was the manager correlated to the different investment styles?
#
# Main methods used:
#
# 1. Style attribution
#
# A decomposition based on active risk factor exposures. Typical model: Fama-French framework, value, momentum, size, market.
# 2. Return decomposition, also often called "Brinson attribution"
#
# A decomposition based on active weights. Many flavors, but typical one includes security selection, allocation, and interaction.
#
# In what cases should you use one over the other?

# %% [markdown]
# A brief overview of Brinson attribution
# BHB vs BF models.

# %% [markdown]
# Let's focus first on style attribution data. Let's check the contribution of the value and momentum factors to the S&P 500 returns in the first month of 2017.
#
# Download the daily values of the S&P 500, as well as the value and momentum factors applied to the S&P 500 from:
# http://us.spindices.com/indices/equity/sp-500
#
# http://us.spindices.com/indices/strategy/sp-500-momentum-index-us-dollar
#
# http://us.spindices.com/indices/equity/sp-500-value

# %% [markdown]
# To assess style attribution, we run a regression analysis, with our portfolio returns as the dependant variable and the different factors we are interested in as the explanatory variables.
#
# Our regression model will follow the form:
#
# portfolio returns = alpha + value + momentum + other factors of interest.
#
# The regression equation gives us the betas, or coefficients, for each of these factors.
#
# Multiplying these betas with the returns those factors delivered over the period allows us to know what proportion of our portfolio's performance was due to each of these specific factors.
#
# The model is very important here. If we don't include all the relevant factors as explanatory variables, we may overestimate the alpha in this portfolio. Adding factors to the model will "explain away" increasing parts of this alpha.
#
# Note: in using the results of your regression model, make sure to check the t statistic for each coefficient, to make sure it is also statistically significant. Furthermore, check your overall R squared for your model, to check the overall explanatory power of your factors.

# %%
styles = pd.read_csv("S&P 500 styles attribution data.csv")
styles
# Out:
#        Date    SP500  SP500Value  SP500Momentum  SP500Growth
# 0    1/3/17  4315.08     4720.28         938.47      3016.40
# 1    1/4/17  4340.75     4747.46         941.48      3034.86
# 2    1/5/17  4337.45     4728.99         944.44      3041.01
# 3    1/6/17  4354.05     4736.55         946.29      3058.65
# 4    1/9/17  4338.62     4705.46         943.36      3055.94
# 5   1/10/17  4338.64     4708.81         941.70      3054.07
# 6   1/11/17  4351.32     4725.82         942.86      3061.14
# 7   1/12/17  4342.09     4711.32         943.33      3057.20
# 8   1/13/17  4350.11     4718.35         944.45      3063.79
# 9   1/17/17  4337.20     4696.73         946.86      3059.04
# 10  1/18/17  4345.57     4704.76         947.62      3065.52
# 11  1/19/17  4329.96     4680.02         945.69      3058.98
# 12  1/20/17  4344.67     4697.41         947.79      3068.52
# 13  1/23/17  4333.10     4676.22         950.01      3065.30
# 14  1/24/17  4361.56     4713.36         950.01      3081.77
# 15  1/25/17  4396.57     4755.08         954.11      3104.29
# 16  1/26/17  4393.43     4749.11         953.68      3103.54
# 17  1/27/17  4389.85     4733.89         956.33      3107.48
# 18  1/30/17  4363.67     4705.63         952.02      3088.96
# 19  1/31/17  4359.81     4708.19         952.04      3082.41

# %%
formula_styles = 'SP500 ~ SP500Value + SP500Momentum + SP500Growth'
test2 = smf.ols(formula_styles, data = styles).fit()
print(test2.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  SP500   R-squared:                       1.000
# Model:                            OLS   Adj. R-squared:                  1.000
# Method:                 Least Squares   F-statistic:                 1.905e+08
# Date:                Sun, 12 Nov 2017   Prob (F-statistic):           1.26e-60
# Time:                        16:49:14   Log-Likelihood:                 84.742
# No. Observations:                  20   AIC:                            -161.5
# Df Residuals:                      16   BIC:                            -157.5
# Df Model:                           3
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# Intercept         0.4231      0.304      1.390      0.184      -0.222       1.068
# SP500Value        0.4306   4.34e-05   9914.279      0.000       0.431       0.431
# SP500Momentum    -0.0010      0.001     -1.967      0.067      -0.002    8.14e-05
# SP500Growth       0.7568      0.000   6727.084      0.000       0.757       0.757
# ==============================================================================
# Omnibus:                        1.657   Durbin-Watson:                   2.028
# Prob(Omnibus):                  0.437   Jarque-Bera (JB):                0.561
# Skew:                           0.371   Prob(JB):                        0.756
# Kurtosis:                       3.351   Cond. No.                     1.99e+06
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.99e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %% [markdown]
# The S&P was up 1.04% in January 2017.
# To assess what part of this performance was due to growth for example, we multiply the beta for growth here, 0.75, by the returns of this factor over the same period.
#
# Note: this model is for illustration only, and is not very meaningful in itself. Look at the multicollinearity warning. This means our predicting factors are highly correlated among themselves. When this is the case, our coefficient estimates are unstable and difficult to interpret.
#
# For more on multicollinearity see Frost (2013).
# For a very good discussion on style attribution, see Israel (2016).

# %% [markdown]
# # Brinson attribution

# %%
brinson = pd.read_csv('brinson_attribution.csv')
brinson.head(5)
# Out:
#                    Sector  Net Port Weight%  Bench Weight%  \
# 0  Consumer Discretionary              2.33          12.15
# 1        Consumer Staples              0.56           9.33
# 2                  Energy              1.63           5.88
# 3              Financials             11.32          18.00
# 4             Health Care              0.11          12.29
#
#    Bench Sector Weight  Bench Sector Return  Portfolio Sector Weight (Long)%  \
# 0              12.1461               0.0049                          14.6369
# 1               9.3314               0.0019                           2.1062
# 2               5.8823               0.0055                           1.6256
# 3              18.0013               0.0036                          11.3228
# 4              12.2863               0.0152                           3.3389
#
#    Portfolio Sector Weight (Short)%  Porfolio Return Long  \
# 0                          -12.3063               -0.0040
# 1                           -1.5497                0.0056
# 2                            0.0000               -0.0010
# 3                            0.0000                0.0035
# 4                           -3.2260                0.0200
#
#    Portfolio Return Short
# 0                  0.0023
# 1                  0.0050
# 2                  0.0000
# 3                  0.0000
# 4                  0.0148

# %% [markdown]
# To calculate the allocation effect:
#
# Formula:
#
# (portfolio sector weight - benchmark sector weight) * benchmark sector return
#
# You do this for each sector.
#
# You do this on the long side, and on the short side.
#
# You then add the results for the long and short sides in order to get the total allocation effect.

# %% [markdown]
# Allocation effect: did the overweighting or underweighting of certain sectors compared to the benchmark contribute positively or negatively to the total portfolio returns?
#
# Positive allocation effect occurs when the manager/model overweights a sector that outperforms the benchmark overall, or when the manager/model underweights a sector that underperforms the benchmark overall.
# Negative allocation effect is of course the opposite.

# %%
brinson['allocation_long'] = (brinson['Portfolio Sector Weight (Long)%'] - brinson['Bench Weight%']) * brinson['Bench Sector Return']
brinson['allocation_short'] = (brinson['Portfolio Sector Weight (Short)%'] - brinson['Bench Weight%']) * brinson['Bench Sector Return']
brinson['allocation'] = brinson['allocation_long'] - brinson['allocation_short']
brinson['allocation']
# Out:
# 0     0.132022
# 1     0.006946
# 2     0.008941
# 3     0.040762
# 4     0.099786
# 5     0.056452
# 6     0.099488
# 7     0.055401
# 8     0.030201
# 9     0.000000
# 10    0.026531
# Name: allocation, dtype: float64

# %% [markdown]
# Selection effect: the manager/model skill in selecting securities within each segment, relative to the benchmark.
#
# Positive selection effect: model/manager selected securities within each segment that outperformed similar securities in the benchmark.
# Negative selection effect: the opposite of course.

# %% [markdown]
# To calculate the selection effect:
#
# Formula:
#
# (portfolio sector return - benchmark sector return) * benchmark sector weight

# %%
brinson['selection_long'] = (brinson['Porfolio Return Long'] - brinson['Bench Sector Return']) * brinson['Bench Weight%']
brinson['selection_short'] = (brinson['Portfolio Return Short'] - brinson['Bench Sector Return']) * brinson['Bench Weight%']
brinson['selection'] = brinson['selection_long'] - brinson['selection_short']
brinson['selection']
# Out:
# 0    -0.076545
# 1     0.005598
# 2    -0.005880
# 3     0.063000
# 4     0.063908
# 5     0.038556
# 6     0.170448
# 7    -0.002535
# 8     0.011951
# 9     0.000000
# 10    0.003310
# Name: selection, dtype: float64

# %% [markdown]
# To calculate the selection effect:
#
# Formula:
#
# (portfolio sector weight - benchmark sector weight) * (portfolio sector return - benchmark sector return)

# %% [markdown]
# The interaction effect is more difficult to understand. It is simply the effect of the interaction between the selection and allocation effects, and not the result of a specific investment decision/process.

# %%
brinson['interaction_long'] = (brinson['Portfolio Sector Weight (Long)%'] - brinson['Bench Weight%'])*(brinson['Porfolio Return Long'] - brinson['Bench Sector Return'])
brinson['interaction_short'] = (brinson['Portfolio Sector Weight (Short)%'] - brinson['Bench Weight%'])*(brinson['Portfolio Return Short'] - brinson['Bench Sector Return'])
brinson['interaction'] = brinson['interaction_long'] - brinson['interaction_short']
brinson['interaction']
# Out:
# 0    -0.085720
# 1     0.006999
# 2    -0.004686
# 3    -0.064132
# 4    -0.049172
# 5    -0.061335
# 6    -0.129326
# 7    -0.056834
# 8    -0.024415
# 9     0.000000
# 10   -0.016575
# Name: interaction, dtype: float64

# %% [markdown]
# The total active management effect is the sum of the selection, allocation, and interaction effects.
#
# Total active management effect = allocation + selection + interaction

# %% [markdown]
# A couple of comments on attribution:
#
# 1. Attribution needs to match the manager style i.e. top down vs bottom up
# 2. BHB vs BF
# 3. Interaction effect remains elusive to interpret

# %% [markdown]
# Other portfolio analytics to explore:
#
# Uniqueness
#
# Overlap
#
# Leverage
#
# VaR

# %% [markdown]
# ## Most common mistakes in risk analytics
#
# Not understanding the units of a measure
#
# Not understanding the period of a measure
#
# Not understanding the concept behind a measure

# %% [markdown]
# ## Bibliography and references
#
# Adrian, Tobias, Markus Brunnermeier, and Hoai-Luu Nguyen. "Hedge Fund Tail Risk." (n.d.): n. pag. Web.
#
# Altshuller, Stan. How to Analyze Manager Skill with Limited Transparency. Rep. Novus. N.p.: n.p., 2016. Print.
#
# Altshuller, Stan. Which Hedge FundsAreWorth the High Fees? Which Hedge Funds Are Worth the High Fees?
#
# Angelini, Luca, and Andrea Gentilini. Batting Average and Win-Loss Ratio Applications. 2015, Batting Average and Win-Loss Ratio Applications.
#
# Bailey, David & Lopez de Prado, Marcos. (2014). The Deflated Sharpe Ratio: Correcting for Selection Bias, Backtest Overfitting, and Non-Normality. The Journal of Portfolio Management. 40. 94-107. 10.3905/jpm.2014.40.5.094.
#
# Board of Governors of the Federal Reserve System (US), 1-Month Treasury Constant Maturity Rate [DGS1MO], retrieved from FRED, Federal Reserve Bank of St. Louis; https://fred.stlouisfed.org/series/DGS1MO, October 15, 2017.
#
# Brinson, Gary P., L. Randolph Hood, and Gilbert L. Beebower. "Determinants of Portfolio Performance." Financial Analysts Journal 51.1 (1995): 133-38. Web.
#
# “Definition of ‘Beta’ - NASDAQ Financial Glossary.” NASDAQ.com, NASDAQ, www.nasdaq.com/investing/glossary/b/beta.
#
# DiBartolomeo, Dan. “Evaluating Active Manager Skill.” Oct. 2014, Webinar, Webinar.
#
# DiBartolomeo, Dan. The Near-Death Experience of Quant Asset Management. Northfield, 2013, The Near-Death Experience of Quant Asset Management.
#
# Eling M., Schuhmacher F. (2006) Performance Measurement of Hedge Fund Indices - Does the Measure Matter?. In: Haasis HD., Kopfer H., Schönberger J. (eds) Operations Research Proceedings 2005. Operations Research Proceedings, vol 2005. Springer, Berlin, Heidelberg
#
# Equity Performance Attribution. Rep. Morningstar. N.p.: Morningstar, 2011. Print.
#
# Erickson, Darrin. Interpreting Performance Attribution. Rep. CFA Institute. N.p.: CFA Institute, 2011. Print.
#
# Favre, Laurent, and Jose-Antonio Galeano. An Analysis of Hedge Fund Performance Using Loess Fit Regression. Tech. EDHEC Business School. N.p.: n.p., 2002. Print.
#
# Feibel, Bruce J. Investment Performance Measurement. N.p.: John Wiley & Sons, 2003. Print.
#
# Ferson, Wayne. Investment Performance Evaluation. Working paper no. CenFIS Working Paper 10-01. N.p.: Federal Reserve Bank of Atlanta, 2010. Print.
#
# Frost, Jim. “What Are the Effects of Multicollinearity and When Can I Ignore Them?” Minitab, 2 May 2013, blog.minitab.com/blog/adventures-in-statistics-2/what-are-the-effects-of-multicollinearity-and-when-can-i-ignore-them.
#
# Gehin, Walter. A Survey of the Literature on Hedge Fund Performance. Rep. A Survey of the Literature on Hedge Fund Performance. N.p.: n.p., 2004. Print.
#
# Gentilini, Andrea, and Stan Altshuller. Your Investment Decisions Are Based on the Wrong Metrics. 2015, Your Investment Decisions Are Based on the Wrong Metrics.
#
# Heydt, Michael. Mastering Pandas for Finance. N.p.: Packt Limited, 2015. Print.
#
# Hilton, Max. RiskMonitor Glossary. Rep. RiskMonitor Clarus Risk. N.p.: Clarus Risk, 2016. Print.
#
# Illmer, Stefan. "Overview of Performance Attribution." N/A. Apr. 2010. Web.
#
# Investment Performance, Analytics and Risk - Glossary of Terms. Rep. J.P. Morgan. N.p.: n.p., 2008. Print.
#
# Investment Statistics Guide. Rep. Evestment. N.p.: n.p., n.d. Print.
#
# Israel, Ronen. Measuring Portfolio Factor Exposures: A Practical Guide. 2016, Measuring Portfolio Factor Exposures: A Practical Guide.
#
# Keating, Con, and William Shadwick. An Introduction to Omega. The Finance Development Centre, 2002, An Introduction to Omega.
#
# Kidd, Deborah. Risk-Adjusted Performance Measures: A Case Study. Rep. CFA Institute. N.p.: CFA Institute, 2012. Print.
#
# Ledoit, Oliver, and Michael Wolf. "Robust Performance Hypothesis Testing with the Sharpe Ratio." Journal of Empirical Finance 15.5 (2008): 850-59. Web.
#
# Leerink, Bas, and Gerard Van Breukelen. Multi-Period Performance Attribution. Working paper no. Applied Paper No. 2015-01. Ortec Finance. N.p.: Ortec Finance Research Center, 2015. Print.
#
# Lo, Andrew. Where Do Alphas Come From?: A New Measure of the Value of Active Investment Management. Rep. MIT. N.p.: n.p., 2007. Web.
#
# Marty, Wolfgang. Portfolio Analytics: An Introduction to Return and Risk Measurement. N.p.: Springer International, 2013. Print.
#
# Petajisto, Antti. "Active Share and Mutual Fund Performance." CFA Institute Event. 28 Oct. 2013. Lecture.
#
# Rollinger, Thomas, and Scott Hoffman. Sortino: A 'Sharper' Ratio. Red Rock Capital, 2015, Sortino: A 'Sharper' Ratio, www.redrockcapital.com/ResearchWhitePapers.html.
#
# Ryan, Timothy. Time Matters in Performance Analysis. Rep. CFA Institute. N.p.: CFA Institute, 2010. Print.
#
# Securing Investment Returns in the Long Run - GFRI teaching team at the University of Geneva
# https://www.coursera.org/learn/investment-returns-long-run/lecture/g5VrE/performance-attribution-example
# [on performance attribution]
#
# The Journal of Performance Measurement: http://www.spauldinggrp.com/the-journal/
#
# Till, Hillary. Measuring Risk-Adjusted Returns in Alternative Investments. Rep. EDHEC Business School. N.p.: n.p., 2006. Print.
#
# Yan, Yuxing. Python for Finance: Build Real-Life Python Applications for Quantitative Finance and Financial Engineering. Packt Publishing Limited, 2014.
#
# Yuen, Raymond. "WORKSHOP FOR USING EXCEL FOR FINANCE PART 6." Web.

# %% [markdown]
# ## Thanks to:
# [none of these individuals have reviewed the present work, yet all taught me more than I can describe here]
#
# Pr. Wicher Bergsma, LSE
#
# Pr. Roy Henk, Kyoto University
#
# Pr. Marco Cuturi, ENSAE
#
# Raymond Yuen, who kindly shared some of his work with me and whose tutorials I highly recommend
#
# Con Keating, who kindly authorised me to share some of his terrific work
#
# Max Hilton and the entire team at Clarus Risk, which have built a premier investment analytics and risk firm, and who provide independent risk analytics on our own funds:
# info@clarusrisk.com

# %% [markdown]
# ## Legal disclaimer:
# This tutorial reflects purely and solely my own personal opinions.
# Empiric Capital and its affiliated companies have had no input to this tutorial.
# Recipients should form their own assessment and take independent professional advice on the merits of investing in general and the legal, regulatory, tax and investment consequences and risks of so doing. In preparing this document, the author has relied upon and assumed, without independent verification, the accuracy and completeness of all information available from public sources or which was otherwise used in the preparation of this document. The author accepts no responsibility to any person for the consequences of any person placing reliance on the content of this document for any purpose.
# No part of this tutorial is to be understood or used as investment advice.
